# %%
string = """superman@worker3:~$ gmdeploy list

存在配置信息异常:
dev_add_UserType_PermissionManager未使用
dev_total_item_pay_round未使用
master未使用
release_pay_first未使用
release_sale_manager_with_partner_id2未使用
fix_finance_search_bug未使用


manage运行信息
---------
分支: dev_account
模板分支: release-upms
端口: 8880
灰度信息: ['482', '255', '342', '341', '396', '495', '402', '5', '388']
---------
分支: master_last_purchase
模板分支: release-master_old
端口: 8881
灰度信息: ['1']
---------
分支: dev_add_UserType_PermissionManager
模板分支: master
端口: 8882
灰度信息: 未使用
---------
分支: dev_total_item_pay_round
模板分支: master
端口: 8883
灰度信息: 未使用
---------
分支: master
模板分支: master
端口: 8884
灰度信息: 未使用
---------
分支: release_pay_first
模板分支: release-money_first_ma
端口: 8885
灰度信息: 未使用
---------
分支: release_sale_manager_with_partner_id2
模板分支: master
端口: 8886
灰度信息: 未使用
---------
分支: fix_finance_search_bug
模板分支: master
端口: 8887
灰度信息: 未使用
---------
分支: fix_finance_export
模板分支: master
端口: 8888
灰度信息: ['default']

存在配置信息异常:
fix_out_stock_sheet未使用
release_pay_first未使用
fix_suppier_exception未使用
fix_order_price_update未使用
***端口8571不存在运行分支
fix_order_details_import未使用
master未使用


station运行信息
---------
分支: fix_out_stock_sheet
模板分支: master
端口: 8576
灰度信息: 未使用
---------
分支: release_pay_first
模板分支: release-money_first_station
端口: 8577
灰度信息: 未使用
---------
分支: fix_suppier_exception
模板分支: master
端口: 8578
灰度信息: 未使用
---------
分支: fix_openapi_pay_status
模板分支: master
端口: 8579
灰度信息: ['266', '421']
---------
分支: fix_order_price_update
模板分支: master
端口: 8580
灰度信息: 未使用
---------
分支: temp_stbf_master
模板分支: release-stbf
端口: 8581
灰度信息: ['260', '292', '305']
---------
分支: zql_tmp
模板分支: master
端口: 8572
灰度信息: ['default', '428']
---------
分支: fix_order_details_import
模板分支: master
端口: 8573
灰度信息: 未使用
---------
分支: dev_account
模板分支: release-upms
端口: 8574
灰度信息: ['482', '255', '342', '341', '396', '495', '402', '5', '388']
---------
分支: master
模板分支: master
端口: 8575
灰度信息: 未使用

存在配置信息异常:
master未使用
release_pay_first未使用


bshop运行信息
---------
分支: master
模板分支: master
端口: 8610
灰度信息: 未使用
---------
分支: release_pay_first
模板分支: release-money_first_bshop
端口: 8611
灰度信息: 未使用
---------
分支: dev_enhance_password
模板分支: release-master_old
端口: 8612
灰度信息: ['xnn']
---------
分支: fix_pay_first_gray
模板分支: master
端口: 8613
灰度信息: ['default']
superman@worker3:~$"""

# %%
for i in ['288', '309', '403', '218', '314', '304', '259', '435', '160', '377', '388', '324', '299']:
    if i in string:
        print(i)
# Out:
# 388
